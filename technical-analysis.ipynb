# %%
from backtesting import Backtest, Strategy
from backtesting.test import GOOG
from backtesting.lib import crossover
import yfinance as yf
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # [Backtesting.py Tutorial](https://www.youtube.com/watch?v=e4ytbIm2Xg0)

# %%
print(GOOG)
# Out:
#               Open    High     Low   Close    Volume
# 2004-08-19  100.00  104.06   95.96  100.34  22351900
# 2004-08-20  101.01  109.08  100.50  108.31  11428600
# 2004-08-23  110.75  113.48  109.05  109.40   9137200
# 2004-08-24  111.24  111.60  103.57  104.87   7631300
# 2004-08-25  104.96  108.00  103.88  106.00   4598900
# ...            ...     ...     ...     ...       ...
# 2013-02-25  802.30  808.41  790.49  790.77   2303900
# 2013-02-26  795.00  795.95  784.40  790.13   2202500
# 2013-02-27  794.80  804.75  791.11  799.78   2026100
# 2013-02-28  801.10  806.99  801.03  801.20   2265800
# 2013-03-01  797.80  807.14  796.15  806.19   2175400
#
# [2148 rows x 5 columns]

# %% [markdown]
# ---

# %%
goog_stock_data = yf.download('GOOG','2004-08-19')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
goog_stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...                ...         ...         ...         ...         ...
# 2022-11-23   97.339996   99.069000   97.339996   98.820000   98.820000
# 2022-11-25   98.464996   98.940002   97.529999   97.599998   97.599998
# 2022-11-28   97.199997   97.830002   95.889999   96.250000   96.250000
# 2022-11-29   96.000000   96.389999   94.389999   95.440002   95.440002
# 2022-12-01  101.400002  102.589996  100.669998  101.279999  101.279999
#
#                Volume
# Date
# 2004-08-19  897427216
# 2004-08-20  458857488
# 2004-08-23  366857939
# ...

# %%
plt.figure(figsize=(15, 15))

plt.ylabel('GOOG Closing Price')

goog_stock_data.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date', ylabel='GOOG Closing Price'>

# %%
stock_data = yf.download('QQQ','2004-08-19')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19   33.730000   33.849998   33.410000   33.669998   29.031910
# 2004-08-20   33.570000   34.139999   33.509998   34.009998   29.325077
# 2004-08-23   34.049999   34.270000   33.910000   34.090000   29.394066
# 2004-08-24   34.250000   34.310001   33.810001   34.080002   29.385441
# 2004-08-25   34.070000   34.599998   33.900002   34.549999   29.790688
# ...                ...         ...         ...         ...         ...
# 2022-11-25  287.190002  287.910004  286.420013  286.920013  286.920013
# 2022-11-28  284.899994  286.959991  281.760010  282.709991  282.709991
# 2022-11-29  282.940002  283.350006  279.170013  280.570007  280.570007
# 2022-11-30  280.839996  293.470001  279.970001  293.359985  293.359985
# 2022-12-01  293.690002  295.750000  290.880005  293.720001  293.720001
#
#                Volume
# Date
# 2004-08-19  104690200
# 2004-08-20   91962400
# 2004-08-23   83390800
# ...

# %%
plt.figure(figsize=(15, 15))

plt.ylabel('QQQ Closing Price')

stock_data.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date', ylabel='QQQ Closing Price'>

# %% [markdown]
# I want to put this plot on my webpage
#
# https://towardsdatascience.com/python-plotting-api-expose-your-scientific-python-plots-through-a-flask-api-31ec7555c4a8

# %% [markdown]
# Or this
#
# https://medium.com/dsights/export-charts-from-jupyter-notebook-to-flask-app-with-few-lines-of-code-ad4dca134ba
